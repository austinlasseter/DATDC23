# %% [markdown]
# # Project 1 - Iowa Liquor
#
# You are a data scientist in residence at the Iowa State tax board. The Iowa State legislature is considering changes in the liquor tax rates and wants a report of current liquor sales by county and projections for the rest of the year.
#
# Your task is as follows:
#
# * Calculate the yearly liquor sales for each store using the provided data. You can add up the transactions for each year, and store sales in 2015 specifically will be used later as your target variable.
# * Use the data from 2015 to make a linear model using as many variables as you find useful to predict the yearly sales of all stores. You must use the sales from Jan to March as one of your variables.
# * Use your model for 2015 to estimate total sales in 2016, extrapolating from the sales so far for Jan-March of 2016.
# * Report your findings, including any projected increase or decrease in total sales (over the entire state) for the tax committee of the Iowa legislature.
# * Use cross-validation to check how your model predicts to held out data compared to the model metrics on the full dataset.
# * Fit your model(s) using one or both of the regularization tactics covered. Explain whether the regularized or the non-regularized model performed better and what the selected regression(s) are doing.
#
#
#
# # Part 1
#
# ### Data Cleaning and EDA
#
# In Part 1 of this two-part project, you will apply the skills you have learned manipulating data in Python with Pandas, Numpy, Matplotlib, Seaborn and other tools to import the Iowa Liquor data, clean the dataset, then perform exploratory analysis using visual and statistical methods.
#
# ### Requirements:
#
# **Identify the problem**
# - Write a high quality problem statement
# - Describe the goals of your study and criteria for success
#
# **Acquire and clean the data**
# - Verify the dataset is in the 'Assets' folder of this project - the data is from [Iowa.gov](https://data.iowa.gov/Economy/Iowa-Liquor-Sales/m3tr-qhgy), filtered and
# reduced
# - Import data using the Pandas Library
# - Format, clean, slice, and combine the data in Python
#
# **Explore the data**
# - Perform exploratory analysis methods with visualization and statistical analysis
# - Determine outliers, skew distribution of important variables (if any)
# - Determine correlations / causations in the data
# - State the risks and assumptions of your data
# - Identify 5 relationships, trends, or other intersting attributes of the data set

# %% [markdown]
# # Identify the Problem
#
# The goal of this two-part project is to build a model predicting future sales. Write a problem statement and identify SMART goals

# %% [markdown]
# ### Problem Statement
#
# _write your problem statement here_

# %% [markdown]
# ### SMART Goals
#
# _write your SMART goals here_

# %% [markdown]
# # Download Data

# %% [markdown]
# If you navigate to the [data.iowa.gov](https://data.iowa.gov/Economy/Iowa-Liquor-Sales/m3tr-qhgy) page for the liquor sales data and click "download" - you'll end up with a 3.4GB/12.6 million row file containing all transactions by product for every class-E liquor store in the state since January 1, 2012
#
# For this project, we are providing a trimmed version of this dataset which contains a sample of the data. If you would like to try using a larger sample of the data, reach out to John or Joseph

# %% [markdown]
# ** The folowing code verifies that the dataset is in the right location **
#
# If the code below returns 'false' - reach out to your instructors.

# %%
import os
os.path.isfile('../Assets/Iowa_Liquor_sample.csv')
# Out:
# True

# %% [markdown]
# # Load Data and Clean
#
# Start by loading the data with pandas. You may need to parse the date columns appropriately.

# %%
import pandas as pd
import numpy as np

# %%
## Load the data into a DataFrame
liquor=pd.read_csv('../Assets/Iowa_Liquor_sample.csv')

# %% [markdown]
# ### Explore the head and tail
#
# View the head and tail of the data set; take a look at the columns.
#
# Can you identify what each of the columns are describing?
#
# How many rows / columns are there in the dataset?

# %%
# How many rows / columns are there in the dataset?
liquor.shape
# Out:
# (270955, 18)

# %%
# View the head of the data set
liquor.head()
# Out:
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  11/04/2015          3717       SUMNER    50674            9.0      Bremer
# 1  03/02/2016          2614    DAVENPORT    52807           82.0       Scott
# 2  02/11/2016          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3  02/03/2016          2501         AMES    50010           85.0       Story
# 4  08/18/2015          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750             $4.50
# 1                    Tin Cup                 750            $13.75
# 2                   Jim Beam                1000            $12.59
# 3    1800 Ultimate Margarita                1750             $9.50
# 4         Five O'clock Vodka                1750             $7.20
#
#   State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0               $6.75            12         $81.00                   9.0
# 1              $20.63             2         $41.26                   1.5
# 2              $18.89            24        $453.36                  24.0
# 3              $14.25             6         $85.50                  10.5
# 4              $10.80            12        $129.60                  21.0
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40
# 2                   6.34
# 3                   2.77
# 4                   5.55

# %%
# view the tail of the dataset
liquor.tail()
# Out:
#               Date  Store Number             City Zip Code  County Number  \
# 270950  12/22/2015          4057       DES MOINES    50316           77.0
# 270951  11/04/2015          5151        IDA GROVE    51445           47.0
# 270952  10/20/2015          5152         WATERLOO    50702            7.0
# 270953  11/20/2015          3562  WEST BURLINGTON    52655           29.0
# 270954  01/27/2015          4446        URBANDALE    50322           77.0
#
#             County   Category                       Category Name  \
# 270950        Polk  1022100.0                             TEQUILA
# 270951         Ida  1011200.0           STRAIGHT BOURBON WHISKIES
# 270952  Black Hawk  1011300.0                  TENNESSEE WHISKIES
# 270953  Des Moines  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 270954        Polk  1031080.0                      VODKA 80 PROOF
#
#         Vendor Number  Item Number               Item Description  \
# 270950            410        88291     Patron Tequila Silver Mini
# 270951            259        17956      Evan Williams Str Bourbon
# 270952             85        26826  Jack Daniels Old #7 Black Lbl
# 270953            192        65258           Jagermeister Liqueur
# 270954            260        37993          Smirnoff Vodka 80 Prf
#
#         Bottle Volume (ml) State Bottle Cost State Bottle Retail  \
# 270950                 300            $20.30              $30.45
# 270951                 750             $7.47              $11.21
# 270952                 750            $15.07              $22.61
# 270953                1750            $26.05              $39.08
# 270954                 200             $2.75               $4.13
#
#         Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 270950             4        $121.80                  1.20
# 270951             3         $33.63                  2.25
# 270952             6        $135.66                  4.50
# 270953             6        $234.48                 10.50
# 270954             8         $33.04                  1.60
#
#         Volume Sold (Gallons)
# 270950                   0.32
# 270951                   0.59
# 270952                   1.19
# 270953                   2.77
# 270954                   0.42

# %% [markdown]
# ### Parse dates
#
# Using '.dtypes' on our dataframe allows us to view the data type of each of our collumns. Pandas does its best to infer data types on ingest, but we may still need to make assumptions. [Pandas Dtype Basics](https://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes)

# %%
# use .dtypes on the liquor dataframe to view the data type of each column
liquor.dtypes
# Out:
# Date                      object
# Store Number               int64
# City                      object
# Zip Code                  object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number              int64
# Item Number                int64
# Item Description          object
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtype: object

# %% [markdown]
# Note that the 'Date' column has the dtype 'object' - this is the pandas data type designation for a string or a data type it doesn't recognise.
#
# We want our 'Date' column to be interpreted as datatime by pandas so we can perform time-based grouping and other functions on this column, so we have to convert it to a datetime datatype.
#
# Pandas gives us some options:
# - Adjust our pd.read_csv to infer datetimes on import
# - Directly convert the date column
#
# [Pandas pd.read_csv datetime handling documentation](https://pandas.pydata.org/pandas-docs/stable/io.html#datetime-handling)
#
# [Pandas pd.to_datetime documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)

# %%
# Option: convert the 'Date' column
liquor["Date"] = pd.to_datetime(liquor["Date"],errors='coerce',infer_datetime_format=True)
liquor.dtypes
# Out:
# Date                     datetime64[ns]
# Store Number                      int64
# City                             object
# Zip Code                         object
# County Number                   float64
# County                           object
# Category                        float64
# Category Name                    object
# Vendor Number                     int64
# Item Number                       int64
# Item Description                 object
# Bottle Volume (ml)                int64
# State Bottle Cost                object
# State Bottle Retail              object
# Bottles Sold                      int64
# Sale (Dollars)                   object
# Volume Sold (Liters)            float64
# Volume Sold (Gallons)           float64
# dtype: object

# %%
# Option: adjust pd.read_csv
liquor = pd.read_csv('../Assets/Iowa_Liquor_sample.csv',parse_dates=['Date'],infer_datetime_format=True)
liquor.dtypes
# Out:
# Date                     datetime64[ns]
# Store Number                      int64
# City                             object
# Zip Code                         object
# County Number                   float64
# County                           object
# Category                        float64
# Category Name                    object
# Vendor Number                     int64
# Item Number                       int64
# Item Description                 object
# Bottle Volume (ml)                int64
# State Bottle Cost                object
# State Bottle Retail              object
# Bottles Sold                      int64
# Sale (Dollars)                   object
# Volume Sold (Liters)            float64
# Volume Sold (Gallons)           float64
# dtype: object

# %% [markdown]
# ### Clean Column Names
#
# Are there spaces in the column names? When columns have spaces in there name, it makes it difficult to use pandas in the form of df.column.method() (ie, liquor.City.value_counts)
#
# For a multi-word column name, you would have to use df['Zip Code'] instead of df.ZipCode
#
# Additionally, some of our columns have parantheses in their names.
#
# We can remove spaces and special characters from our columns, which will help keep our code clean.

# %%
# view  column names
liquor.columns.values
# Out:
# array(['Date', 'Store Number', 'City', 'Zip Code', 'County Number',
#        'County', 'Category', 'Category Name', 'Vendor Number',
#        'Item Number', 'Item Description', 'Bottle Volume (ml)',
#        'State Bottle Cost', 'State Bottle Retail', 'Bottles Sold',
#        'Sale (Dollars)', 'Volume Sold (Liters)', 'Volume Sold (Gallons)'], dtype=object)

# %%
# remove spaces
liquor.columns = liquor.columns.str.replace(' ','')
liquor.columns.values
# Out:
# array(['Date', 'StoreNumber', 'City', 'ZipCode', 'CountyNumber', 'County',
#        'Category', 'CategoryName', 'VendorNumber', 'ItemNumber',
#        'ItemDescription', 'BottleVolume(ml)', 'StateBottleCost',
#        'StateBottleRetail', 'BottlesSold', 'Sale(Dollars)',
#        'VolumeSold(Liters)', 'VolumeSold(Gallons)'], dtype=object)

# %%
# remove left parentheses
liquor.columns = liquor.columns.str.replace('(','')
liquor.columns.values
# Out:
# array(['Date', 'StoreNumber', 'City', 'ZipCode', 'CountyNumber', 'County',
#        'Category', 'CategoryName', 'VendorNumber', 'ItemNumber',
#        'ItemDescription', 'BottleVolumeml)', 'StateBottleCost',
#        'StateBottleRetail', 'BottlesSold', 'SaleDollars)',
#        'VolumeSoldLiters)', 'VolumeSoldGallons)'], dtype=object)

# %%
# remove right parentheses
liquor.columns = liquor.columns.str.replace(')','')
liquor.columns.values
# Out:
# array(['Date', 'StoreNumber', 'City', 'ZipCode', 'CountyNumber', 'County',
#        'Category', 'CategoryName', 'VendorNumber', 'ItemNumber',
#        'ItemDescription', 'BottleVolumeml', 'StateBottleCost',
#        'StateBottleRetail', 'BottlesSold', 'SaleDollars',
#        'VolumeSoldLiters', 'VolumeSoldGallons'], dtype=object)

# %% [markdown]
# ### Clean Numerics
#
# Look at the .dtypes and the .head() of the dataframe again - are there any columns that should be a numeric data type (float, int, etc) that are still objects? (hint - follow the $money)
#
# [Pandas Series.replace()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.replace.html)
#
# [Pandas pd.to_numeric()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_numeric.html)

# %%
liquor.dtypes
# Out:
# Date                 datetime64[ns]
# StoreNumber                   int64
# City                         object
# ZipCode                      object
# CountyNumber                float64
# County                       object
# Category                    float64
# CategoryName                 object
# VendorNumber                  int64
# ItemNumber                    int64
# ItemDescription              object
# BottleVolumeml                int64
# StateBottleCost              object
# StateBottleRetail            object
# BottlesSold                   int64
# SaleDollars                  object
# VolumeSoldLiters            float64
# VolumeSoldGallons           float64
# dtype: object

# %%
liquor['StateBottleCost'].head()
# Out:
# 0     $4.50
# 1    $13.75
# 2    $12.59
# 3     $9.50
# 4     $7.20
# Name: StateBottleCost, dtype: object

# %%
# remove characters from a series of strings/objects
liquor['StateBottleCost'] = liquor['StateBottleCost'].str.replace('$','')
liquor['StateBottleCost'].head()
# Out:
# 0     4.50
# 1    13.75
# 2    12.59
# 3     9.50
# 4     7.20
# Name: StateBottleCost, dtype: object

# %%
liquor['StateBottleRetail'] = liquor['StateBottleRetail'].str.replace('$','')
liquor['StateBottleRetail'].head()
# Out:
# 0     6.75
# 1    20.63
# 2    18.89
# 3    14.25
# 4    10.80
# Name: StateBottleRetail, dtype: object

# %%
liquor['SaleDollars'] = liquor['SaleDollars'].str.replace('$','')
liquor['SaleDollars'].head()
# Out:
# 0     81.00
# 1     41.26
# 2    453.36
# 3     85.50
# 4    129.60
# Name: SaleDollars, dtype: object

# %%
# convert string/object columns to numeric
liquor['StateBottleCost'] = pd.to_numeric(liquor['StateBottleCost'], errors='coerce')
liquor['StateBottleRetail'] = pd.to_numeric(liquor['StateBottleRetail'], errors='coerce')
liquor['SaleDollars'] = pd.to_numeric(liquor['SaleDollars'], errors='coerce')
liquor.dtypes
# Out:
# Date                 datetime64[ns]
# StoreNumber                   int64
# City                         object
# ZipCode                      object
# CountyNumber                float64
# County                       object
# Category                    float64
# CategoryName                 object
# VendorNumber                  int64
# ItemNumber                    int64
# ItemDescription              object
# BottleVolumeml                int64
# StateBottleCost             float64
# StateBottleRetail           float64
# BottlesSold                   int64
# SaleDollars                 float64
# VolumeSoldLiters            float64
# VolumeSoldGallons           float64
# dtype: object

# %%
# examine your .dtypes and .head() to confirm your type adjustements
liquor.head()
# Out:
#         Date  StoreNumber         City ZipCode  CountyNumber      County  \
# 0 2015-11-04         3717       SUMNER   50674           9.0      Bremer
# 1 2016-03-02         2614    DAVENPORT   52807          82.0       Scott
# 2 2016-02-11         2106  CEDAR FALLS   50613           7.0  Black Hawk
# 3 2016-02-03         2501         AMES   50010          85.0       Story
# 4 2015-08-18         3654      BELMOND   50421          99.0      Wright
#
#     Category               CategoryName  VendorNumber  ItemNumber  \
# 0  1051100.0           APRICOT BRANDIES            55       54436
# 1  1011100.0           BLENDED WHISKIES           395       27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES            65       19067
# 3  1071100.0         AMERICAN COCKTAILS           395       59154
# 4  1031080.0             VODKA 80 PROOF           297       35918
#
#              ItemDescription  BottleVolumeml  StateBottleCost  \
# 0  Mr. Boston Apricot Brandy             750             4.50
# 1                    Tin Cup             750            13.75
# 2                   Jim Beam            1000            12.59
# 3    1800 Ultimate Margarita            1750             9.50
# 4         Five O'clock Vodka            1750             7.20
#
#    StateBottleRetail  BottlesSold  SaleDollars  VolumeSoldLiters  \
# 0               6.75           12        81.00               9.0
# 1              20.63            2        41.26               1.5
# 2              18.89           24       453.36              24.0
# 3              14.25            6        85.50              10.5
# 4              10.80           12       129.60              21.0
#
#    VolumeSoldGallons
# 0               2.38
# 1               0.40
# 2               6.34
# 3               2.77
# 4               5.55

# %% [markdown]
# ### Null Values
#
# Evaluate the null values in the dataset.
#
# Questions to guide your process:
# - What columns have null values?
# - How many nulls values are in each column?
# - Will the missing values effect your analysis?
# - Can you afford to remove (drop) the null values from your dataset?
#
# [df.isnull()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.isnull.html)
#
# [df.dropna()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html)
#
# [O'Reilly article on dealing with nulls using pandas](https://www.oreilly.com/learning/handling-missing-data)
#
# [Data School video on missing values in pandas](https://www.youtube.com/watch?v=fCMrO_VzeL8)

# %%
liquor.isnull().sum()
# Out:
# Date                    0
# StoreNumber             0
# City                    0
# ZipCode                 0
# CountyNumber         1077
# County               1077
# Category               68
# CategoryName          632
# VendorNumber            0
# ItemNumber              0
# ItemDescription         0
# BottleVolumeml          0
# StateBottleCost         0
# StateBottleRetail       0
# BottlesSold             0
# SaleDollars             0
# VolumeSoldLiters        0
# VolumeSoldGallons       0
# dtype: int64

# %%
# Show rows with missing data.
liquor[liquor.isnull().any(axis=1)]
# Out:
#              Date  StoreNumber          City ZipCode  CountyNumber  \
# 135    2016-01-20         5222  CEDAR RAPIDS   52402           NaN
# 198    2016-03-02         3820    SIOUX CITY   51103           NaN
# 272    2016-03-21         4222     EVANSDALE   50707           NaN
# 290    2016-03-21         5236       ANAMOSA   52205           NaN
# 321    2016-02-23         4203       WAVERLY   50677           NaN
# 863    2016-01-11         2460       HAMPTON   50441           NaN
# 896    2015-02-05         4829    DES MOINES   50314          77.0
# 901    2016-02-25         4647      WATERLOO   50707           7.0
# 964    2015-05-19         4247       BELMOND   50421           NaN
# 982    2016-03-30         5222  CEDAR RAPIDS   52402           NaN
# 1024   2016-03-23         3820    SIOUX CITY   51103           NaN
# 1514   2016-02-18         2515    MASON CITY   50401          17.0
# 1630   2016-02-10         5224    CORALVILLE   52241           NaN
# 1667   2016-03-30         2637     DAVENPORT   52804           NaN
# 1684   2016-02-08         3747     SIGOURNEY   52591          54.0
# 1798   2016-03-03         5227       CLINTON   52732           NaN
# 2084   2016-03-24         5229       NORWALK   50211           NaN
# 2176   2016-03-21         5236       ANAMOSA   52205           NaN
# 2203   2016-02-16         4589        SIBLEY   51249          72.0
# 2533   2016-03-09         2637     DAVENPORT   52804           NaN
# 2549   2016-03-22         5210      CLARINDA   51632           NaN
# 2678   2016-03-29         5210      CLARINDA   51632           NaN
# 2871   2015-09-22         4247       BELMOND   50421           NaN
# 2894   2016-02-09         2413       DUBUQUE   52001          31.0
# 3071   2016-02-15         2539    IOWA FALLS   50126          42.0
# 3246   2016-03-16         3820    SIOUX CITY   51103           NaN
# 3482   2016-02-10         3524          AMES   50010          85.0
# 3939   2016-03-21         5236       ANAMOSA   52205           NaN
# 4015   2016-03-16         2637     DAVENPORT   52804           NaN
# 4448   2015-03-03         4247       BELMOND   50421           NaN
# ...           ...          ...           ...     ...           ...
# 265904 2016-02-18         2248    DES MOINES   50312          77.0
# 266383 2015-09-08         4247       BELMOND   50421           NaN
# 266646 2015-12-17         2633    DES MOINES   50320          77.0
# 266660 2016-03-02         3820    SIOUX CITY   51103           NaN
# 266801 2016-03-03         5220    MASON CITY   50401           NaN
# 266806 2016-03-22         4006     LARCHWOOD   51241           NaN
# 266852 2016-02-23         4167       DUBUQUE   52001          31.0
# 266961 2016-03-21         2650        HARLAN   51537           NaN
# 267727 2016-02-23         4712       DUBUQUE   52001          31.0
# 267729 2016-03-07         2650        HARLAN   51537           NaN
# 268016 2016-02-17         2596       OTTUMWA   52501          90.0
# 268130 2016-02-22         4794    BURLINGTON   52601          29.0
# 268186 2016-02-08         5214  CEDAR RAPIDS   52404           NaN
# 268475 2016-02-16         5230  CEDAR RAPIDS   52402           NaN
# 268504 2016-02-23         4247       BELMOND   50421           NaN
# 269000 2016-01-25         2460       HAMPTON   50441           NaN
# 269080 2016-03-22         5230  CEDAR RAPIDS   52402           NaN
# 269414 2016-03-16         4169    DES MOINES   50317           NaN
# 269449 2016-03-23         2637     DAVENPORT   52804           NaN
# 269457 2015-10-19         2633    DES MOINES   50320          77.0
# 269482 2016-03-01         5210      CLARINDA   51632           NaN
# 269715 2016-03-16         2637     DAVENPORT   52804           NaN
# 269751 2016-02-17         5128    DES MOINES   50310          77.0
# 269885 2016-02-04         4648      WATERLOO   50703           7.0
# 269953 2015-11-30         4229        HARLAN   51537          83.0
# 269982 2016-02-22         2460       HAMPTON   50441           NaN
# 270031 2015-05-12         4247       BELMOND   50421           NaN
# 270046 2016-02-17         2637     DAVENPORT   52804          82.0
# 270083 2016-03-21         5236       ANAMOSA   52205           NaN
# 270654 2016-02-17         2572   CEDAR FALLS   50613           7.0
#
#              County   Category                        CategoryName  \
# 135             NaN  1051010.0             AMERICAN GRAPE BRANDIES
# 198             NaN  1032080.0                      IMPORTED VODKA
# 272             NaN  1062300.0                        FLAVORED RUM
# 290             NaN  1081600.0                     WHISKEY LIQUEUR
# 321             NaN  1051100.0                    APRICOT BRANDIES
# 863             NaN  1011200.0           STRAIGHT BOURBON WHISKIES
# 896            Polk  1022200.0                                 NaN
# 901      Black Hawk  1052100.0                                 NaN
# 964             NaN  1012100.0                   CANADIAN WHISKIES
# 982             NaN  1031080.0                      VODKA 80 PROOF
# 1024            NaN  1081390.0                   IMPORTED SCHNAPPS
# 1514    Cerro Gordo  1082100.0                                 NaN
# 1630            NaN  1062310.0                          SPICED RUM
# 1667            NaN  1041100.0                   AMERICAN DRY GINS
# 1684         Keokuk  1052100.0                                 NaN
# 1798            NaN  1031080.0                      VODKA 80 PROOF
# 2084            NaN  1012100.0                   CANADIAN WHISKIES
# 2176            NaN  1031080.0                      VODKA 80 PROOF
# 2203        Osceola  1032100.0                                 NaN
# 2533            NaN  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
# 2549            NaN  1022100.0                             TEQUILA
# 2678            NaN  1012100.0                   CANADIAN WHISKIES
# 2871            NaN  1062300.0                        FLAVORED RUM
# 2894        Dubuque  1082100.0                                 NaN
# 3071         Hardin  1052100.0                                 NaN
# 3246            NaN  1032080.0                      IMPORTED VODKA
# 3482          Story  1032100.0                                 NaN
# 3939            NaN  1022100.0                             TEQUILA
# 4015            NaN  1081330.0                      PEACH SCHNAPPS
# 4448            NaN  1031080.0                      VODKA 80 PROOF
# ...             ...        ...                                 ...
# 265904         Polk  1052100.0                                 NaN
# 266383          NaN  1031080.0                      VODKA 80 PROOF
# 266646         Polk  1091100.0                                 NaN
# 266660          NaN  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 266801          NaN  1031080.0                      VODKA 80 PROOF
# 266806          NaN  1012100.0                   CANADIAN WHISKIES
# 266852      Dubuque  1052100.0                                 NaN
# 266961          NaN  1011100.0                    BLENDED WHISKIES
# 267727      Dubuque  1052100.0                                 NaN
# 267729          NaN  1011200.0           STRAIGHT BOURBON WHISKIES
# 268016      Wapello  1052100.0                                 NaN
# 268130   Des Moines  1032100.0                                 NaN
# 268186          NaN  1011200.0           STRAIGHT BOURBON WHISKIES
# 268475          NaN  1032200.0               IMPORTED VODKA - MISC
# 268504          NaN  1062310.0                          SPICED RUM
# 269000          NaN  1031080.0                      VODKA 80 PROOF
# 269080          NaN  1701100.0      DECANTERS & SPECIALTY PACKAGES
# 269414          NaN  1031200.0                      VODKA FLAVORED
# 269449          NaN  1011300.0                  TENNESSEE WHISKIES
# 269457         Polk  1022200.0                                 NaN
# 269482          NaN  1012210.0                  SINGLE MALT SCOTCH
# 269715          NaN  1081200.0                      CREAM LIQUEURS
# 269751         Polk  1032100.0                                 NaN
# 269885   Black Hawk  1052100.0                                 NaN
# 269953       Shelby        NaN                                 NaN
# 269982          NaN  1081600.0                     WHISKEY LIQUEUR
# 270031          NaN  1081390.0                   IMPORTED SCHNAPPS
# 270046        Scott  1082100.0                                 NaN
# 270083          NaN  1052010.0             IMPORTED GRAPE BRANDIES
# 270654   Black Hawk  1032100.0                                 NaN
#
#         VendorNumber  ItemNumber                     ItemDescription  \
# 135              115       53214     Paul Masson Grande Amber Brandy
# 198               35       34359                    Grey Goose Vodka
# 272              370       42716                  Malibu Coconut Rum
# 290              421       64868           Fireball Cinnamon Whiskey
# 321              434       55084         Paramount Blackberry Brandy
# 863              461       77776          Wild Turkey American Honey
# 896               85        3657        Herradura Gold Reposado 6pak
# 901              420       48099                         Hennessy VS
# 964               55       12408                 Canadian Ltd Whisky
# 982              300       36904                 Mccormick Vodka Pet
# 1024             421       69637  Dr. Mcgillicuddy's Cherry Schnapps
# 1514             420       67487       Grand Marnier Raspberry Peach
# 1630             260       43337           Captain Morgan Spiced Rum
# 1667             260       30318       Gordon's Gin London Dry - Pet
# 1684             420       48106                  Hennessy Vs Cognac
# 1798             297       35926              Five O'clock PET Vodka
# 2084             260       11296                         Crown Royal
# 2176              55       37938                          Skol Vodka
# 2203             115       34821                        Svedka Vodka
# 2533             434       45278                 Paramount White Rum
# 2549              35       89099                     Cazadores Anejo
# 2678              65       10627                Canadian Club Whisky
# 2871              65       44428           Cruzan Blueberry Lemonade
# 2894             130       64136                  Disaronno Amaretto
# 3071             420       48106                  Hennessy Vs Cognac
# 3246             260       36871                  Ciroc Luxury Vodka
# 3482             115       34821                        Svedka Vodka
# 3939             434       87937               Juarez Tequila Silver
# 4015              65       82844         Dekuyper Peachtree Schnapps
# 4448             380       37338                        UV Vodka PET
# ...              ...         ...                                 ...
# 265904           420       48105                         Hennessy VS
# 266383           297       35916                  Five O'clock Vodka
# 266646           434      933934                       Pearl Caramel
# 266660            65       85526     Dekuyper Signature Blue Curacao
# 266801           434       36308                       Hawkeye Vodka
# 266806            65       15248                Windsor Canadian Pet
# 266852           420       48105                         Hennessy VS
# 266961            65       22784            Beam's 8 Star Bl Whiskey
# 267727           420       48105                         Hennessy VS
# 267729            65       19067                            Jim Beam
# 268016           420       48106                  Hennessy Vs Cognac
# 268130           277       34746    Stolichnaya Premium Vodka 80 Prf
# 268186            65       19476                        Maker's Mark
# 268475           260       64572                     Ciroc Pineapple
# 268504           260       43418               Captain Morgan Tattoo
# 269000           260       37418                  Popov Vodka 80 Prf
# 269080            65       36409               Effen Football Sleeve
# 269414           205       40289               New Amsterdam Coconut
# 269449            85       26585                      Gentleman Jack
# 269457            85        3657        Herradura Gold Reposado 6pak
# 269482           260        5696             Oban Single Malt Scotch
# 269715           962       80143         Forbidden Secret Dark Mocha
# 269751           115       34821                        Svedka Vodka
# 269885           420       48106                  Hennessy Vs Cognac
# 269953           255         297               Templeton Rye w/Flask
# 269982           259       86626                     Cold Spell Mint
# 270031           421       69667          Dr. Mcgillicuddy's Vanilla
# 270046           420       65126          Grand Marnier Cordon Rouge
# 270083           420       48164             Hennessy VSOP Privilege
# 270654           277       34746    Stolichnaya Premium Vodka 80 Prf
#
#         BottleVolumeml  StateBottleCost  StateBottleRetail  BottlesSold  \
# 135                375             3.22               4.83           24
# 198                200             5.00               7.50           12
# 272                750             7.49              11.24            3
# 290               1750            15.33              23.00            6
# 321                375             3.55               5.33           24
# 863                750            10.50              15.75            3
# 896                750            23.58              35.37            6
# 901                200             5.74               8.61           24
# 964               1750             9.14              13.71            6
# 982                375             1.80               2.70           24
# 1024              1000            11.00              16.50           24
# 1514               750            23.31              34.97            2
# 1630              1000            11.75              17.63           12
# 1667              1750            11.00              16.50            6
# 1684               750            18.99              28.49            2
# 1798               750             3.37               5.06           12
# 2084               750            15.00              22.50           12
# 2176              1750             7.11              10.67            2
# 2203              1750            14.74              22.11            2
# 2533              1750             7.84              11.76            6
# 2549               750            23.33              35.00            1
# 2678              1000             9.71              14.57           12
# 2871               750             6.83              10.25            1
# 2894               750            13.86              20.79           12
# 3071               750            18.99              28.49            3
# 3246               750            18.49              27.74            1
# 3482              1750            14.74              22.11            6
# 3939              1000             6.92              10.38           12
# 4015               375             3.07               4.61            4
# 4448              1750            10.49              15.99            6
# ...                ...              ...                ...          ...
# 265904             375             9.99              14.99            4
# 266383             750             3.37               5.06           12
# 266646            1000             8.67              13.01           24
# 266660             750             5.25               7.88           24
# 266801            1750             7.17              10.76            6
# 266806            1750             9.45              14.18            6
# 266852             375             9.99              14.99           72
# 266961             375             2.09               3.14            4
# 267727             375             9.99              14.99            2
# 267729            1000            12.59              18.89           12
# 268016             750            18.99              28.49            1
# 268130             750            11.99              17.99           12
# 268186             750            17.32              25.98           12
# 268475             375             9.25              13.88            4
# 268504             750             9.00              13.50            2
# 269000            1750             8.50              12.75            6
# 269080             750            18.89              28.34            1
# 269414             750             6.90              10.35            2
# 269449             375             6.55               9.83            2
# 269457             750            23.58              35.37            6
# 269482             750            40.50              60.75            1
# 269715             750            11.79              17.69            6
# 269751            1750            14.74              22.11            6
# 269885             750            18.99              28.49           12
# 269953             750            18.09              27.14           12
# 269982             750             7.47              11.21            2
# 270031            1000            11.00              16.50            1
# 270046             750            23.31              34.97            4
# 270083             750            29.99              44.99            1
# 270654             750            11.99              17.99            2
#
#         SaleDollars  VolumeSoldLiters  VolumeSoldGallons
# 135          115.92              9.00               2.38
# 198           90.00              2.40               0.63
# 272           33.72              2.25               0.59
# 290          138.00             10.50               2.77
# 321          127.92              9.00               2.38
# 863           47.25              2.25               0.59
# 896          212.22              4.50               1.19
# 901          206.64              4.80               1.27
# 964           82.26             10.50               2.77
# 982           64.80              9.00               2.38
# 1024         396.00             24.00               6.34
# 1514          69.94              1.50               0.40
# 1630         211.56             12.00               3.17
# 1667          99.00             10.50               2.77
# 1684          56.98              1.50               0.40
# 1798          60.72              9.00               2.38
# 2084         270.00              9.00               2.38
# 2176          21.34              3.50               0.92
# 2203          44.22              3.50               0.92
# 2533          70.56             10.50               2.77
# 2549          35.00              0.75               0.20
# 2678         174.84             12.00               3.17
# 2871          10.25              0.75               0.20
# 2894         249.48              9.00               2.38
# 3071          85.47              2.25               0.59
# 3246          27.74              0.75               0.20
# 3482         132.66             10.50               2.77
# 3939         124.56             12.00               3.17
# 4015          18.44              1.50               0.40
# 4448          95.94             10.50               2.77
# ...             ...               ...                ...
# 265904        59.96              1.50               0.40
# 266383        60.72              9.00               2.38
# 266646       312.24             24.00               6.34
# 266660       189.12             18.00               4.76
# 266801        64.56             10.50               2.77
# 266806        85.08             10.50               2.77
# 266852      1079.28             27.00               7.13
# 266961        12.56              1.50               0.40
# 267727        29.98              0.75               0.20
# 267729       226.68             12.00               3.17
# 268016        28.49              0.75               0.20
# 268130       215.88              9.00               2.38
# 268186       311.76              9.00               2.38
# 268475        55.52              1.50               0.40
# 268504        27.00              1.50               0.40
# 269000        76.50             10.50               2.77
# 269080        28.34              0.75               0.20
# 269414        20.70              1.50               0.40
# 269449        19.66              0.75               0.20
# 269457       212.22              4.50               1.19
# 269482        60.75              0.75               0.20
# 269715       106.14              4.50               1.19
# 269751       132.66             10.50               2.77
# 269885       341.88              9.00               2.38
# 269953       325.68              9.00               2.38
# 269982        22.42              1.50               0.40
# 270031        16.50              1.00               0.26
# 270046       139.88              3.00               0.79
# 270083        44.99              0.75               0.20
# 270654        35.98              1.50               0.40
#
# [1697 rows x 18 columns]

# %%
# Drop any column with all missing data.
liquor.dropna(axis=1, how='all').inplace=True
liquor.isnull().sum()
# Out:
# Date                    0
# StoreNumber             0
# City                    0
# ZipCode                 0
# CountyNumber         1077
# County               1077
# Category               68
# CategoryName          632
# VendorNumber            0
# ItemNumber              0
# ItemDescription         0
# BottleVolumeml          0
# StateBottleCost         0
# StateBottleRetail       0
# BottlesSold             0
# SaleDollars             0
# VolumeSoldLiters        0
# VolumeSoldGallons       0
# dtype: int64

# %%
# Drop any row with some missing data.
liquor.dropna(axis=0, how='any').inplace=True
liquor.isnull().sum()
# Out:
# Date                    0
# StoreNumber             0
# City                    0
# ZipCode                 0
# CountyNumber         1077
# County               1077
# Category               68
# CategoryName          632
# VendorNumber            0
# ItemNumber              0
# ItemDescription         0
# BottleVolumeml          0
# StateBottleCost         0
# StateBottleRetail       0
# BottlesSold             0
# SaleDollars             0
# VolumeSoldLiters        0
# VolumeSoldGallons       0
# dtype: int64

# %%
# Not really sure what this code is for. It was just here.
test = {'col1':[1,2,3],'col2':['a','b','c']}
test['col1'] = [4,5,6]
pd.liquor(test)
liquor[liquor.isnull().any(axis=1)]
cols = ['col1','col2']

for col in cols:
    df[col] = df[col].replace
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-1c0b1f6afbe6> in <module>()
#       2 test = {'col1':[1,2,3],'col2':['a','b','c']}
#       3 test['col1'] = [4,5,6]
# ----> 4 pd.liquor(test)
#       5 liquor[liquor.isnull().any(axis=1)]
#       6 cols = ['col1','col2']
#
# AttributeError: 'module' object has no attribute 'liquor'

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Using pandas (and other tools such as NumPy, Matplotlib, or Seaborn) explore the Iowa Liquor dataset.
#
# **Remember** Your goal in Part 2 will be to predict future sales. Look for relationships, trends, and features that may assist you in that task.
#
# ### Identify 5 trends, relationships, or things that stand out to you in the dataset
#
# Display yout findings below

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Some questions to get you started:
#
#  - What categories had the highest number of sales?
#  - What categories had the highest sales in dollars?
#  - Are there any strong relationships between any of the features and sales (in dollars)?
#  - Are there any outliers? Are there any individual sales, stores, locations, or categories that show strange behavior?
#  - What categories are the most profitable?
#  - What stores are the most profitable?

# %% [markdown]
# ** Example **
#
# Relationship between mean Bottles Sold and average SaleDollars (by store)
#
# There is a strong possitive relationship between the average number of bottles sold per transaction at a store and the average total sale amount per transaction at the same store.
#
# Digging deeper, by comparing BottlesSold to StateBottleRetai we can see that there is almost no relationship between the average bottle price per transaction at a store and the average number of bottles sold per transaction; that is stores which are selling more bottles per transaction are not nescesarily selling cheaper items, and stores that are selling less bottles are not selling more expensive items.

# %%
# group by store.
liquor.groupby('StoreNumber').BottlesSold.mean()

# %%
liquor.groupby('StoreNumber').BottlesSold.mean().plot(kind='bar')

# %%
# sort by store and category.
liquor.sort_values(by=['StoreNumber']).inplace=True
liquor.head()

# %%
# graphing relationship between mean Bottles Sold per store and mean Sale total per store
liquor_grouped_mean = liquor.groupby('StoreNumber')
liquor_grouped_mean.head()
# Out:
#              Date  StoreNumber             City ZipCode  CountyNumber  \
# 0      2015-11-04         3717           SUMNER   50674           9.0
# 1      2016-03-02         2614        DAVENPORT   52807          82.0
# 2      2016-02-11         2106      CEDAR FALLS   50613           7.0
# 3      2016-02-03         2501             AMES   50010          85.0
# 4      2015-08-18         3654          BELMOND   50421          99.0
# 5      2015-04-20         2569     CEDAR RAPIDS   52402          57.0
# 6      2015-08-05         2596          OTTUMWA   52501          90.0
# 7      2015-06-25         3456       CLEAR LAKE   50428          17.0
# 8      2016-01-04         4757        BONDURANT   50035          77.0
# 9      2015-11-10         4346       SHELLSBURG   52332           6.0
# 10     2015-09-28         2648  WEST DES MOINES   50265          77.0
# 11     2015-10-28         2600        OSKALOOSA   52577          62.0
# 12     2015-01-22         3858        DAVENPORT   52806          82.0
# 13     2016-02-29         4673       WEST POINT   52656          56.0
# 14     2016-01-04         2670       CORALVILLE   52241          52.0
# 15     2015-06-10         3717           SUMNER   50674           9.0
# 16     2016-02-25         2130         WATERLOO   50703           7.0
# 17     2015-12-29         2600        OSKALOOSA   52577          62.0
# 18     2015-12-26         4604           NEWTON   50208          50.0
# 19     2015-03-04         2614        DAVENPORT   52807          82.0
# 20     2015-01-16         2590     CEDAR RAPIDS   52402          57.0
# 21     2015-01-13         3942           TOLEDO   52342          86.0
# 22     2015-03-24         3981     SIOUX CENTER   51250          84.0
# 23     2015-11-12         4376       MASON CITY   50401          17.0
# 24     2016-03-14         2618     CEDAR RAPIDS   52402          57.0
# 25     2015-02-03         3390          MILFORD   51351          30.0
# 26     2015-11-23         3565        IOWA CITY   52246          52.0
# 27     2015-04-21         3963   COUNCIL BLUFFS   51501          78.0
# 28     2015-12-01         4375           GRIMES   50111          77.0
# 29     2015-01-14         2545        IOWA CITY   52245          52.0
# ...           ...          ...              ...     ...           ...
# 215118 2016-03-22         5237       FORT DODGE   50501           NaN
# 216036 2015-01-15         2961  WEST DES MOINES   50265          77.0
# 216569 2015-01-06         4990         GRISWOLD   51535          15.0
# 223058 2015-09-01         4497            ALDEN   50006          42.0
# 223079 2015-07-06         5056   COUNCIL BLUFFS   51501          78.0
# 224202 2015-10-21         4610            FONDA   50540          76.0
# 227424 2016-03-31         5229          NORWALK   50211           NaN
# 228217 2015-05-07         5139         WATERLOO   50703           7.0
# 231121 2016-03-24         5229          NORWALK   50211           NaN
# 232175 2016-03-30         4737       STORM LAKE   50588          11.0
# 234840 2016-03-09         5216         RUNNELLS   50237           NaN
# 237259 2015-09-16         4778       STORM LAKE   50588          11.0
# 240044 2015-04-14         4497            ALDEN   50006          42.0
# 240143 2015-03-24         5033         WATERLOO   50702           7.0
# 242632 2015-01-06         4059     BELLE PLAINE   52208           6.0
# 243246 2016-03-22         5237       FORT DODGE   50501           NaN
# 243873 2016-03-08         4929             ADEL   50003          25.0
# 247828 2015-12-01         5201          DUBUQUE   52001          31.0
# 249568 2016-03-24         5229          NORWALK   50211           NaN
# 250055 2015-03-10         4990         GRISWOLD   51535          15.0
# 253984 2016-03-09         5233    PLEASANTVILLE   50225           NaN
# 254013 2015-10-19         5189  WEST DES MOINES   50266          77.0
# 254595 2015-11-05         5139         WATERLOO   50703           7.0
# 255805 2016-02-08         5195   COUNCIL BLUFFS   51530          78.0
# 255967 2015-01-08         4939        URBANDALE   50322          77.0
# 259754 2016-01-20         5130        DAVENPORT   52801          82.0
# 268097 2015-01-06         4990         GRISWOLD   51535          15.0
# 268382 2015-01-08         4939        URBANDALE   50322          77.0
# 269711 2015-01-06         4335           INWOOD   51240          60.0
# 269725 2015-01-13         4059     BELLE PLAINE   52208           6.0
#
#                County   Category                      CategoryName  \
# 0              Bremer  1051100.0                  APRICOT BRANDIES
# 1               Scott  1011100.0                  BLENDED WHISKIES
# 2          Black Hawk  1011200.0         STRAIGHT BOURBON WHISKIES
# 3               Story  1071100.0                AMERICAN COCKTAILS
# 4              Wright  1031080.0                    VODKA 80 PROOF
# 5                Linn  1041100.0                 AMERICAN DRY GINS
# 6             Wapello  1051010.0           AMERICAN GRAPE BRANDIES
# 7         Cerro Gordo  1012100.0                 CANADIAN WHISKIES
# 8                Polk  1032080.0                    IMPORTED VODKA
# 9              Benton  1081315.0                 CINNAMON SCHNAPPS
# 10               Polk  1011250.0    SINGLE BARREL BOURBON WHISKIES
# 11            Mahaska  1071100.0                AMERICAN COCKTAILS
# 12              Scott  1012100.0                 CANADIAN WHISKIES
# 13                Lee  1081300.0               PEPPERMINT SCHNAPPS
# 14            Johnson  1031200.0                    VODKA FLAVORED
# 15             Bremer  1051100.0                  APRICOT BRANDIES
# 16         Black Hawk  1031100.0                   100 PROOF VODKA
# 17            Mahaska  1031200.0                    VODKA FLAVORED
# 18             Jasper  1081700.0       DISTILLED SPIRITS SPECIALTY
# 19              Scott  1012100.0                 CANADIAN WHISKIES
# 20               Linn  1031200.0                    VODKA FLAVORED
# 21               Tama  1012100.0                 CANADIAN WHISKIES
# 22              Sioux  1011100.0                  BLENDED WHISKIES
# 23        Cerro Gordo  1022100.0                           TEQUILA
# 24               Linn  1031080.0                    VODKA 80 PROOF
# 25          Dickinson  1011300.0                TENNESSEE WHISKIES
# 26            Johnson  1012100.0                 CANADIAN WHISKIES
# 27      Pottawattamie  1011100.0                  BLENDED WHISKIES
# 28               Polk  1031080.0                    VODKA 80 PROOF
# 29            Johnson  1081600.0                   WHISKEY LIQUEUR
# ...               ...        ...                               ...
# 215118            NaN  1012200.0                   SCOTCH WHISKIES
# 216036           Polk  1081200.0                    CREAM LIQUEURS
# 216569           Cass  1012100.0                 CANADIAN WHISKIES
# 223058         Hardin  1062310.0                        SPICED RUM
# 223079  Pottawattamie  1031200.0                    VODKA FLAVORED
# 224202     Pocahontas  1011500.0             STRAIGHT RYE WHISKIES
# 227424            NaN  1081200.0                    CREAM LIQUEURS
# 228217     Black Hawk  1032200.0             IMPORTED VODKA - MISC
# 231121            NaN  1062310.0                        SPICED RUM
# 232175    Buena Vista  1062200.0  PUERTO RICO & VIRGIN ISLANDS RUM
# 234840            NaN  1012100.0                 CANADIAN WHISKIES
# 237259    Buena Vista  1022100.0                           TEQUILA
# 240044         Hardin  1031080.0                    VODKA 80 PROOF
# 240143     Black Hawk  1011200.0         STRAIGHT BOURBON WHISKIES
# 242632         Benton  1031080.0                    VODKA 80 PROOF
# 243246            NaN  1012100.0                 CANADIAN WHISKIES
# 243873         Dallas  1081600.0                   WHISKEY LIQUEUR
# 247828        Dubuque  1032080.0                    IMPORTED VODKA
# 249568            NaN  1011200.0         STRAIGHT BOURBON WHISKIES
# 250055           Cass  1041100.0                 AMERICAN DRY GINS
# 253984            NaN  1022100.0                           TEQUILA
# 254013           Polk  1081600.0                   WHISKEY LIQUEUR
# 254595     Black Hawk  1022100.0                           TEQUILA
# 255805  Pottawattamie  1012100.0                 CANADIAN WHISKIES
# 255967           Polk  1012100.0                 CANADIAN WHISKIES
# 259754          Scott  1011200.0         STRAIGHT BOURBON WHISKIES
# 268097           Cass  1031080.0                    VODKA 80 PROOF
# 268382           Polk  1012300.0                    IRISH WHISKIES
# 269711           Lyon  1081015.0                 IMPORTED AMARETTO
# 269725         Benton  1031100.0                   100 PROOF VODKA
#
#         VendorNumber  ItemNumber                        ItemDescription  \
# 0                 55       54436              Mr. Boston Apricot Brandy
# 1                395       27605                                Tin Cup
# 2                 65       19067                               Jim Beam
# 3                395       59154                1800 Ultimate Margarita
# 4                297       35918                     Five O'clock Vodka
# 5                205       31473                      New Amsterdam Gin
# 6                 85       52806                          Korbel Brandy
# 7                 65       10628                   Canadian Club Whisky
# 8                370       34006           Absolut Swedish Vodka 80 Prf
# 9                 65       82610                     Dekuyper Hot Damn!
# 10                65       19235       Knob Creek Single Barrel Reserve
# 11                55       57148          Chi-Chi's Margarita W/tequila
# 12                65       15248                   Windsor Canadian Pet
# 13               322       75211                          Kinky Liqueur
# 14               380       41705                  Uv Red (cherry) Vodka
# 15                55       54436              Mr. Boston Apricot Brandy
# 16               297       35913                     Five O'clock Vodka
# 17               380       41989                          Uv Cake Vodka
# 18               434       75087                        Juarez Gold Dss
# 19               434       13638           Lord Calvert Canadian Whisky
# 20               971       41474                   44 North Huckleberry
# 21               115       11786                  Black Velvet Traveler
# 22               260       25606            Seagrams 7 Crown Bl Whiskey
# 23               395       89196  Jose Cuervo Especial Reposado Tequila
# 24               297       35926                 Five O'clock PET Vodka
# 25                85       26827          Jack Daniels Old #7 Black Lbl
# 26               260       11290       Crown Royal Canadian Whisky Mini
# 27               434       24156                  Hawkeye Blend Whiskey
# 28               380       37338                           UV Vodka PET
# 29               260       66199                 Piehole Apple Pie Mini
# ...              ...         ...                                    ...
# 215118           260        4626         Buchanan's 12 Yr Deluxe Scotch
# 216036           305       73055                               Rumchata
# 216569           260       11297            Crown Royal Canadian Whisky
# 223058           260       43338              Captain Morgan Spiced Rum
# 223079           380       41601              Uv Blue (raspberry) Vodka
# 224202           255       27102                          Templeton Rye
# 227424           305       73052                               Rumchata
# 228217           260       64722                            Ciroc Peach
# 231121           260       43334              Captain Morgan Spiced Rum
# 232175            35       43126                   Bacardi Superior Rum
# 234840           115       11776                           Black Velvet
# 237259           395       89199   Jose Cuervo Especial Reposado Square
# 240044           297       35926                 Five O'clock PET Vodka
# 240143            65       19066                               Jim Beam
# 242632           434       36305                          Hawkeye Vodka
# 243246           260       11296                            Crown Royal
# 243873           421       64865          Fireball Cinnamon Whiskey PET
# 247828           260       34197                     Ciroc Luxury Vodka
# 249568            65       19066                               Jim Beam
# 250055           370       32237                 Seagrams Extra Dry Gin
# 253984           395       89199   Jose Cuervo Especial Reposado Square
# 254013           421       64866              Fireball Cinnamon Whiskey
# 254595           410       88294                  Patron Silver Tequila
# 255805           260       11290       Crown Royal Canadian Whisky Mini
# 255967           115       11788                           Black Velvet
# 259754            65       19066                               Jim Beam
# 268097           260       36186                  Gordon's Vodka 80 Prf
# 268382           370       15621                           Jameson Mini
# 269711           130       64136                     Disaronno Amaretto
# 269725           300       36886                        Mccormick Vodka
#
#         BottleVolumeml  StateBottleCost  StateBottleRetail  BottlesSold  \
# 0                  750             4.50               6.75           12
# 1                  750            13.75              20.63            2
# 2                 1000            12.59              18.89           24
# 3                 1750             9.50              14.25            6
# 4                 1750             7.20              10.80           12
# 5                 1750            13.32              19.98            6
# 6                  750             6.66               9.99            3
# 7                 1750            15.75              23.63            2
# 8                  750            11.49              17.24            4
# 9                 1000             7.62              11.43            2
# 10                 750            26.24              39.36            6
# 11                1750             6.00               9.25            6
# 12                1750             8.92              13.38            1
# 13                 750            10.00              15.00           12
# 14                1000             7.50              11.25           12
# 15                 750             4.50               6.75            4
# 16                 200             1.13               1.70           48
# 17                 750             6.50               9.75           12
# 18                1000             4.92               7.38           24
# 19                1750             9.97              14.96            6
# 20                 750            14.25              21.38            2
# 21                 750             5.23               7.85           12
# 22                 750             7.00              10.50           12
# 23                 750            10.49              15.74           12
# 24                 750             3.37               5.06           12
# 25                1000            17.90              26.85           24
# 26                 300             7.35              11.03            1
# 27                 750             3.50               5.25            3
# 28                1750            10.99              16.49            6
# 29                 500             4.90               7.35            1
# ...                ...              ...                ...          ...
# 215118             750            21.99              32.99           12
# 216036             750            12.50              18.75           12
# 216569            1000            18.50              27.75            3
# 223058            1750            18.00              27.00           12
# 223079             375             3.45               5.18            3
# 224202             750            18.09              27.14            6
# 227424             375             7.42              11.13            3
# 228217             200             5.00               7.50           72
# 231121             375             5.00               7.50            6
# 232175             750             8.26              12.39           12
# 234840             750             5.23               7.85           12
# 237259             375             5.50               8.25           12
# 240044             750             3.37               5.06           48
# 240143             750            10.49              15.74            7
# 242632             750             3.34               5.01            5
# 243246             750            15.00              22.50           12
# 243873             750             8.98              13.47           24
# 247828             375             9.25              13.88            5
# 249568             750            10.49              15.74            6
# 250055            1000             7.49              11.24            3
# 253984             375             5.50               8.25            6
# 254013             750             8.98              13.47           12
# 254595             375            14.00              21.00           12
# 255805             300             7.35              11.03            2
# 255967            1750            10.45              15.68            1
# 259754             750            10.49              15.74           12
# 268097             750             5.26               7.89           12
# 268382             600            11.88              17.82            1
# 269711             750            13.86              20.79           12
# 269725             750             3.31               4.97            2
#
#         SaleDollars  VolumeSoldLiters  VolumeSoldGallons
# 0             81.00              9.00               2.38
# 1             41.26              1.50               0.40
# 2            453.36             24.00               6.34
# 3             85.50             10.50               2.77
# 4            129.60             21.00               5.55
# 5            119.88             10.50               2.77
# 6             29.97              2.25               0.59
# 7             47.26              3.50               0.92
# 8             68.96              3.00               0.79
# 9             22.86              2.00               0.53
# 10           236.16              4.50               1.19
# 11            55.50             10.50               2.77
# 12            13.38              1.75               0.46
# 13           180.00              9.00               2.38
# 14           135.00             12.00               3.17
# 15            27.00              3.00               0.79
# 16            81.60              9.60               2.54
# 17           117.00              9.00               2.38
# 18           177.12             24.00               6.34
# 19            89.76             10.50               2.77
# 20            42.76              1.50               0.40
# 21            94.20              9.00               2.38
# 22           126.00              9.00               2.38
# 23           188.88              9.00               2.38
# 24            60.72              9.00               2.38
# 25           644.40             24.00               6.34
# 26            11.03              0.30               0.08
# 27            15.75              2.25               0.59
# 28            98.94             10.50               2.77
# 29             7.35              0.50               0.13
# ...             ...               ...                ...
# 215118       395.88              9.00               2.38
# 216036       225.00              9.00               2.38
# 216569        83.25              3.00               0.79
# 223058       324.00             21.00               5.55
# 223079        15.54              1.12               0.30
# 224202       162.84              4.50               1.19
# 227424        33.39              1.12               0.30
# 228217       540.00             14.40               3.80
# 231121        45.00              2.25               0.59
# 232175       148.68              9.00               2.38
# 234840        94.20              9.00               2.38
# 237259        99.00              4.50               1.19
# 240044       242.88             36.00               9.51
# 240143       110.18              5.25               1.39
# 242632        25.05              3.75               0.99
# 243246       270.00              9.00               2.38
# 243873       323.28             18.00               4.76
# 247828        69.40              1.88               0.50
# 249568        94.44              4.50               1.19
# 250055        33.72              3.00               0.79
# 253984        49.50              2.25               0.59
# 254013       161.64              9.00               2.38
# 254595       252.00              4.50               1.19
# 255805        22.06              0.60               0.16
# 255967        15.68              1.75               0.46
# 259754       188.88              9.00               2.38
# 268097        94.68              9.00               2.38
# 268382        17.82              0.60               0.16
# 269711       249.48              9.00               2.38
# 269725         9.94              1.50               0.40
#
# [6947 rows x 18 columns]

# %%
liquor_grouped_mean.tail()

# %%
# seaborn's jointplot provides a scatter of my variables, histograms, and a pearson correlation coefficient

sns.jointplot(x='BottlesSold',y='SaleDollars',data=liquor_grouped_mean)
plt.show()

# %%
# graphing relationship between mean Bottles Sold per store and mean Bottle Retail price per store
sns.jointplot(x='BottlesSold',y='StateBottleRetail',data=liquor_grouped_mean)
plt.show()

# %%
# histogram of average bottle retail price
liquor_grouped_mean[liquor_grouped_mean.StateBottleRetail <= 50].StateBottleRetail.plot(kind='hist')

liquor_grouped_mean.StateBottleRetail.describe()

# %% [markdown]
# ### Finding #1
#
# *description of your finding*

# %%
# your code here

# %% [markdown]
# ### Finding #2
#
# *description of your finding*

# %%
# your code here

# %% [markdown]
# ### Finding #3
#
# *description of your finding*

# %%
# your code here

# %% [markdown]
# ### Finding #4
#
# *description of your finding*

# %%
# your code here

# %% [markdown]
# ### Finding #5
#
# *description of your finding*

# %%
# your code here
