# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
# Import, convert 'Date' col to datetime
liquor=pd.read_csv('../Assets/Iowa_Liquor_sample.csv',parse_dates=['Date'],infer_datetime_format=True)

# format column names
import re

liquor.columns = [re.sub("[^a-zA-Z]+", "", x) for x in liquor.columns]

# remove '$' in values and convert to numeric
adjust_cols = ['StateBottleCost','StateBottleRetail','SaleDollars']

for col in adjust_cols:
    liquor[col] = pd.to_numeric(liquor[col].str.replace('$',''),errors='coerce')

liquor.dropna(inplace=True)

# %%
# calculate profit per sales transaction
liquor['Profit'] = liquor.SaleDollars - (liquor.BottlesSold * liquor.StateBottleCost)

# %%
# Filter to only 2015 
liquor2015 = liquor[liquor.Date.dt.year == 2015]

# %%
liquor2015.head()
# Out:
#         Date  StoreNumber          City ZipCode  CountyNumber       County  \
# 0 2015-11-04         3717        SUMNER   50674           9.0       Bremer
# 4 2015-08-18         3654       BELMOND   50421          99.0       Wright
# 5 2015-04-20         2569  CEDAR RAPIDS   52402          57.0         Linn
# 6 2015-08-05         2596       OTTUMWA   52501          90.0      Wapello
# 7 2015-06-25         3456    CLEAR LAKE   50428          17.0  Cerro Gordo
#
#     Category             CategoryName  VendorNumber  ItemNumber  \
# 0  1051100.0         APRICOT BRANDIES            55       54436
# 4  1031080.0           VODKA 80 PROOF           297       35918
# 5  1041100.0        AMERICAN DRY GINS           205       31473
# 6  1051010.0  AMERICAN GRAPE BRANDIES            85       52806
# 7  1012100.0        CANADIAN WHISKIES            65       10628
#
#              ItemDescription  BottleVolumeml  StateBottleCost  \
# 0  Mr. Boston Apricot Brandy             750             4.50
# 4         Five O'clock Vodka            1750             7.20
# 5          New Amsterdam Gin            1750            13.32
# 6              Korbel Brandy             750             6.66
# 7       Canadian Club Whisky            1750            15.75
#
#    StateBottleRetail  BottlesSold  SaleDollars  VolumeSoldLiters  \
# 0               6.75           12        81.00              9.00
# 4              10.80           12       129.60             21.00
# 5              19.98            6       119.88             10.50
# 6               9.99            3        29.97              2.25
# 7              23.63            2        47.26              3.50
#
#    VolumeSoldGallons  Profit
# 0               2.38   27.00
# 4               5.55   43.20
# 5               2.77   39.96
# 6               0.59    9.99
# 7               0.92   15.76

# %%
# Create a dictionary called agg (what is this for?)
agg_dict = {'StateBottleCost':[np.mean,np.sum],
'SaleDollars':[np.sum,np.mean],
'Profit':[np.median,np.mean,np.sum]}

# %%
# Pass this dictionary to the groupby statement
liquor2015_stores = liquor2015.groupby('StoreNumber').agg(agg_dict)
liquor2015_stores.head()
# Out:
#             Profit                      StateBottleCost          SaleDollars  \
#             median       mean       sum            mean      sum         sum
# StoreNumber
# 2106         57.00  92.665779  48742.20       10.298783  5417.16   146038.70
# 2113         12.39  21.149932   3109.04       10.870544  1597.97     9310.22
# 2130         51.00  95.215652  37229.32        9.822762  3840.70   111583.91
# 2152          7.62  18.351277   2587.53        8.565035  1207.67     7721.08
# 2178         27.00  34.454430   8165.70        9.689831  2296.49    24324.18
#
#
#                    mean
# StoreNumber
# 2106         277.640114
# 2113          63.334830
# 2130         285.380844
# 2152          54.759433
# 2178         102.633671

# %%
# this comes out with StoreNumber as my index, I'll reset it
liquor2015_stores = liquor2015_stores.reset_index()

# %%
# My column names are split. I'll process through them to get single feature names
liquor2015_stores.columns = [['_'.join(col).rstrip('_') for col in liquor2015_stores.columns.values]]
liquor2015_stores.head()
# Out:
#    StoreNumber  Profit_median  Profit_mean  Profit_sum  StateBottleCost_mean  \
# 0         2106          57.00    92.665779    48742.20             10.298783
# 1         2113          12.39    21.149932     3109.04             10.870544
# 2         2130          51.00    95.215652    37229.32              9.822762
# 3         2152           7.62    18.351277     2587.53              8.565035
# 4         2178          27.00    34.454430     8165.70              9.689831
#
#    StateBottleCost_sum  SaleDollars_sum  SaleDollars_mean
# 0              5417.16        146038.70        277.640114
# 1              1597.97          9310.22         63.334830
# 2              3840.70        111583.91        285.380844
# 3              1207.67          7721.08         54.759433
# 4              2296.49         24324.18        102.633671

# %%
# Merge my features and my target on the 'StoreNumber' column
liquor2015_combined = pd.merge(liquor2015_stores,liquor2015,on=['StoreNumber'])

# %%
# define my features
feature_cols = ['StoreNumber', 'Profit_median', 'StateBottleCost_mean', 'SaleDollars_sum']
feature_cols
# Out:
# ['StoreNumber', 'Profit_median', 'StateBottleCost_mean', 'SaleDollars_sum']

# %%
liquor2015_combined.head()
# Out:
#    StoreNumber  Profit_median  Profit_mean  Profit_sum  StateBottleCost_mean  \
# 0         2106           57.0    92.665779     48742.2             10.298783
# 1         2106           57.0    92.665779     48742.2             10.298783
# 2         2106           57.0    92.665779     48742.2             10.298783
# 3         2106           57.0    92.665779     48742.2             10.298783
# 4         2106           57.0    92.665779     48742.2             10.298783
#
#    StateBottleCost_sum  SaleDollars_sum  SaleDollars_mean       Date  \
# 0              5417.16         146038.7        277.640114 2015-08-20
# 1              5417.16         146038.7        277.640114 2015-03-12
# 2              5417.16         146038.7        277.640114 2015-07-30
# 3              5417.16         146038.7        277.640114 2015-01-22
# 4              5417.16         146038.7        277.640114 2015-08-13
#
#           City   ...   ItemNumber                           ItemDescription  \
# 0  CEDAR FALLS   ...        34007              Absolut Swedish Vodka 80 Prf
# 1  CEDAR FALLS   ...        22216                  Woodford Reserve Bourbon
# 2  CEDAR FALLS   ...        69947  Rumple Minze Peppermint Schnapps Liqueur
# 3  CEDAR FALLS   ...        30527                               Hawkeye Gin
# 4  CEDAR FALLS   ...        82637                     Dekuyper Grape Pucker
#
#   BottleVolumeml  StateBottleCost StateBottleRetail  BottlesSold  SaleDollars  \
# 0           1000            14.99             22.49           36       809.64
# 1            750            21.02             31.53            6       189.18
# 2           1000            15.75             23.63           12       283.56
# 3           1000             4.23              6.35           12        76.20
# 4           1000             7.62             11.43           12       137.16
#
#   VolumeSoldLiters  VolumeSoldGallons  Profit
# 0             36.0               9.51  270.00
# 1              4.5               1.19   63.06
# 2             12.0               3.17   94.56
# 3             12.0               3.17   25.44
# 4             12.0               3.17   45.72
#
# [5 rows x 26 columns]

# %%
# Define x and y
X = liquor2015_combined[feature_cols]
y = liquor2015_combined.Profit

# %%
# instantiate & fit my model
linreg = LinearRegression()
linreg.fit(X, y)
print linreg.coef_
# Out:
# [ -8.16820365e-04   1.71400640e+00   6.16474388e-01   7.43003359e-05]

# %%
# pair the feature names with the coefficients using a command called 'zip'
print(pd.Series(list(zip(feature_cols, linreg.coef_))))
# Out:
# 0         (StoreNumber, -0.000816820365469)
# 1            (Profit_median, 1.71400640228)
# 2    (StateBottleCost_mean, 0.616474387925)
# 3       (SaleDollars_sum, 7.4300335858e-05)
# dtype: object

# %%
# perform the sale aggregation steps on the Q1 2016 data
lq_2016 = liquor[liquor.Date.dt.year == 2016]
lq_2016['Profit'] = lq_2016.SaleDollars - (lq_2016.BottlesSold * lq_2016.StateBottleCost)
lq_2016 = lq_2016.groupby('StoreNumber').agg(agg_dict)
lq_2016.columns = ['_'.join(tup).rstrip('_') for tup in lq_2016.columns.values]
lq_2016.head()
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#              Profit_median  Profit_mean  Profit_sum  StateBottleCost_mean  \
# StoreNumber
# 2106                 51.96    80.751429    10174.68             10.363413
# 2113                 12.60    18.742973      693.49             10.709459
# 2130                 51.00    79.387094     9288.29             10.620085
# 2152                  8.38    15.204000      304.08              8.256500
# 2178                 24.96    32.220000     1868.76              9.266379
#
#              StateBottleCost_sum  SaleDollars_sum  SaleDollars_mean
# StoreNumber
# 2106                     1305.79         30478.75        241.894841
# 2113                      396.25          2065.90         55.835135
# 2130                     1242.55         27856.11        238.086410
# 2152                      165.13           904.66         45.233000
# 2178                      537.45          5588.50         96.353448

# %%
# this comes out with StoreNumber as my index, I'll reset it
lq_2016 = lq_2016.reset_index()

# %%
# 2016 predictions
X_all = liquor2015_combined[feature_cols]
y_all = liquor2015_combined.Profit
X_2016 = lq_2016[feature_cols]

# %%
# train on all method
linreg.fit(X_all,y_all)
lq_2016['prediction'] = linreg.predict(X_2016)

# %%
# Show your 2016 year-end prediction for each store
lq_2016[['prediction']].reset_index()
# Out:
#       index  prediction
# 0         0   86.138190
# 1         1   16.771424
# 2         2   84.436509
# 3         3    7.907994
# 4         4   37.275559
# 5         5   22.233786
# 6         6   60.362284
# 7         7   17.085271
# 8         8    7.994119
# 9         9   54.553510
# 10       10  236.225310
# 11       11   59.122362
# 12       12  118.821016
# 13       13   10.717860
# 14       14   15.051394
# 15       15   31.876614
# 16       16   78.809062
# 17       17   11.878751
# 18       18   10.388978
# 19       19   31.487037
# 20       20   28.952292
# 21       21   52.197509
# 22       22   89.790537
# 23       23    6.909842
# 24       24   29.581616
# 25       25   40.719973
# 26       26   38.103803
# 27       27   36.736706
# 28       28   53.391681
# 29       29   50.220327
# ...     ...         ...
# 1250   1250   57.435154
# 1251   1251    4.902751
# 1252   1252   92.282904
# 1253   1253   13.666231
# 1254   1254   49.985487
# 1255   1255   12.166215
# 1256   1256   22.495498
# 1257   1257   29.676433
# 1258   1258   28.813077
# 1259   1259   35.838674
# 1260   1260    7.865523
# 1261   1261    6.061133
# 1262   1262   16.104724
# 1263   1263   24.535081
# 1264   1264   36.454997
# 1265   1265   25.467228
# 1266   1266   64.922511
# 1267   1267    9.713430
# 1268   1268   -0.890748
# 1269   1269   16.808048
# 1270   1270   21.211386
# 1271   1271   15.212594
# 1272   1272    7.985270
# 1273   1273    4.460804
# 1274   1274    9.456170
# 1275   1275  399.751506
# 1276   1276  134.294895
# 1277   1277   90.277972
# 1278   1278   90.366002
# 1279   1279  355.664106
#
# [1280 rows x 2 columns]
