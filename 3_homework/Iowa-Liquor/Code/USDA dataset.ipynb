# %%
# https://www.ers.usda.gov/data-products/county-level-data-sets/county-level-data-sets-download-data/

# %%
import pandas as pd
xl = pd.ExcelFile('/Users/austinlasseter/Downloads/PovertyEstimates.xls')
xl.sheet_names
# Out:
# ['Poverty Data 2016', 'Variable Descriptions']

# %%
df = xl.parse("Poverty Data 2016")
df.head(30)
iowa=df[df['Unnamed: 1']=='IA']
iowa.head(99)

# %%
df = xl.parse("Variable Descriptions")
df.head(30)
# Out:
#                Column variable name  \
# 0                           FIPStxt
# 1                             State
# 2                         Area_name
# 3   Rural-urban_Continuum_Code_2003
# 4         Urban_Influence_Code_2003
# 5   Rural-urban_Continuum_Code_2013
# 6         Urban_Influence_Code_2013
# 7                       POVALL_2016
# 8                    CI90LBAll_2016
# 9                    CI90UBALL_2016
# 10                   PCTPOVALL_2016
# 11                  CI90LBALLP_2016
# 12                  CI90UBALLP_2016
# 13                      POV017_2016
# 14                   CI90LB017_2016
# 15                   CI90UB017_2016
# 16                   PCTPOV017_2016
# 17                  CI90LB017P_2016
# 18                  CI90UB017P_2016
# 19                      POV517_2016
# 20                   CI90LB517_2016
# 21                   CI90UB517_2016
# 22                   PCTPOV517_2016
# 23                  CI90LB517P_2016
# 24                  CI90UB517P_2016
# ...
